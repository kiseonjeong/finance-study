# %% [markdown]
# <a href="https://colab.research.google.com/github/kiseonjeong/finance-study/blob/main/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finterstellar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import logging
logging.getLogger('matplotlib.font_manager').disabled = True            # to remove matplotlib font warning

# %%
import finterstellar as fs

# %%
df = fs.get_price('AAPL', start_date='2022-01-01', end_date='2022-12-31')
print(df)
# Out:
#              AAPL
# 2022-01-03 182.01
# 2022-01-04 179.70
# 2022-01-05 174.92
# 2022-01-06 172.00
# 2022-01-07 172.17
# ...           ...
# 2022-12-23 131.86
# 2022-12-27 130.03
# 2022-12-28 126.04
# 2022-12-29 129.61
# 2022-12-30 129.93
#
# [251 rows x 1 columns]

# %%
fs.draw_chart(df, right='AAPL')

# %%
fs.rsi(df, w=14)
fs.draw_chart(df, left='rsi', right='AAPL')

# %%
fs.indicator_to_signal(df, factor='rsi', buy=20, sell=70)
# Out:
# 2022-01-03    zero
# 2022-01-04    zero
# 2022-01-05    zero
# 2022-01-06    zero
# 2022-01-07    zero
#               ...
# 2022-12-23    zero
# 2022-12-27    zero
# 2022-12-28    zero
# 2022-12-29    zero
# 2022-12-30    zero
# Name: trade, Length: 251, dtype: object

# %%
fs.position(df)
fs.draw_chart(df, left='rsi', right='position_chart')

# %%
fs.evaluate(df, cost=.001)
fs.draw_chart(df, left='acc_rtn_dp', right='AAPL')

# %%
fs.performance(df, rf_rate=0.01)
# Out:
# CAGR: -0.04%
# Accumulated return: -0.04%
# Average return: -0.04%
# Benchmark return : -20.00%
# Number of trades: 1
# Number of win: 0
# Hit ratio: 0.00%
# Investment period: 0.9yrs
# Sharpe ratio: -0.03
# MDD: -27.32%
# Benchmark MDD: -30.75%
